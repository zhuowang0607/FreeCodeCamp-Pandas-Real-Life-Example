# %% [markdown]
# <a href="https://colab.research.google.com/github/zhuowang0607/FreeCodeCamp-Pandas-Real-Life-Example/blob/master/Exercises_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
sales = pd.read_csv(
    '/content/drive/MyDrive/Colab_Datasets/sales_data.csv',
    parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='box',vert = False, figsize=(14,6))
# Out:
# <Axes: >

# %%
sales['Customer_Age'].plot(kind='kde', figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales.describe()
# Out:
#                                 Date            Day           Year  \
# count                         113036  113036.000000  113036.000000
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price  \
# count  113036.000000   113036.000000  113036.000000  113036.000000
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %%
sales['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
sales['Order_Quantity'].size
# Out:
# 113036

# %%
sales['Order_Quantity'].value_counts()
# Out:
# Order_Quantity
# 1     22626
# 2      7650
# 3      5142
# 4      3436
# 6      3076
# 5      3039
# 18     3010
# 7      2993
# 24     2983
# 16     2978
# 9      2948
# 10     2941
# 14     2914
# 15     2906
# 12     2899
# 8      2894
# 13     2878
# 11     2877
# 20     2873
# 26     2868
# 17     2849
# 19     2838
# 21     2782
# 27     2769
# 25     2736
# 22     2712
# 23     2703
# 28     2533
# 29     2339
# 30     2109
# 31      477
# 32      258
# Name: count, dtype: int64

# %%
sales['Order_Quantity'].value_counts().plot(kind='pie',figsize = (6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].head()
# Out:
# 0    2013
# 1    2015
# 2    2014
# 3    2016
# 4    2014
# Name: Year, dtype: int64

# %%
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6),ylabel = 'Sales')
# Out:
# <Axes: ylabel='Sales'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here

# %%
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6),ylabel = 'Sales')
# Out:
# <Axes: xlabel='Month', ylabel='Sales'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
# value_counts() gives descending order by default.

# %%
sales['Country'].value_counts().head(1)
# Out:
# Country
# United States    39206
# Name: count, dtype: int64

# %% [markdown]
# # Which country has the least sales quantity of sales?

# %%
# To change the order in value_counts() use ascending = True
sales['Country'].value_counts(ascending=True).head(1)
# Out:
# Country
# France    10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6), ylabel = 'Sales')
# Out:
# <Axes: xlabel='Country', ylabel='Sales'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# # Create a bar plot showing the 10 least sold products (best sellers):

# %%
sales['Product'].value_counts(ascending=True).head(10).plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Product'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here

# %%
sales[['Profit', 'Country']].boxplot(by='Country', figsize=(10,6)) # When there are two columns instead of one, use df.boxplot rather than df.plot(kind = 'box')
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda a: '{}-{}-{}'.format(a[0], a[1], a[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()
# Out:
# 0   2013-11-26
# 1   2015-11-26
# 2   2014-03-23
# 3   2016-03-23
# 4   2014-05-15
# Name: Calculated_Date, dtype: datetime64[ns]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(24,6))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here

# %%
sales['Revenue'].head()
# Out:
# 0    1100
# 1    1100
# 2    2551
# 3    2238
# 4     568
# Name: Revenue, dtype: int64

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50
sales['Revenue'].head()
# Out:
# 0    1150
# 1    1150
# 2    2601
# 3    2288
# 4     618
# Name: Revenue, dtype: int64

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')]
# Out:
#              Date  Day      Month  Year  Customer_Age             Age_Group  \
# 0      2013-11-26   26   November  2013            19           Youth (<25)
# 1      2015-11-26   26   November  2015            19           Youth (<25)
# 14     2013-08-02    2     August  2013            29  Young Adults (25-34)
# 15     2015-08-02    2     August  2015            29  Young Adults (25-34)
# 16     2013-09-02    2  September  2013            29  Young Adults (25-34)
# ...           ...  ...        ...   ...           ...                   ...
# 112979 2015-09-08    8  September  2015            31  Young Adults (25-34)
# 113000 2014-07-27   27       July  2014            34  Young Adults (25-34)
# 113001 2016-07-27   27       July  2016            34  Young Adults (25-34)
# 113034 2014-03-04    4      March  2014            37        Adults (35-64)
# 113035 2016-03-04    4      March  2016            37        Adults (35-64)
#
# ...

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0] # return number of rows. ".size" will return the number of total elements, as # of rows  *  # of columns.
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]
# Out:
# 104

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here

# %%
sales.loc[sales['Country'] == 'France']['State'].value_counts()
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here

# %%
sales.loc[sales['Country'] == 'France']['State'].value_counts().plot(kind='pie', figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here

# %%
sales['Product_Category'].value_counts()
# Out:
# Product_Category
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories'] ['Sub_Category'].value_counts()

accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here

# %%
accessories.plot(kind='pie', figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes
# Out:
# Sub_Category
# Road Bikes        13430
# Mountain Bikes     8854
# Touring Bikes      3698
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111)
bikes.plot(kind='pie', ax=ax, autopct='%.1f%%', startangle=270, fontsize=12)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here

# %%
sales['Customer_Gender'].value_counts().head(1)
# Out:
# Customer_Gender
# M    58312
# Name: count, dtype: int64

# %%
fig = plt.figure(figsize=(6,6), dpi=150)
ax = plt.subplot(111)
sales['Customer_Gender'].value_counts().plot(kind='pie', ax=ax, autopct='%.1f%%', startangle=270, fontsize=12)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] > 500)].shape[0]
# Out:
# 27259

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here

# %%
sales.sort_values(['Revenue'], ascending=False).head(5)
# Out:
#              Date  Day      Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24       July  2015            52  Adults (35-64)
# 112072 2013-07-24   24       July  2013            52  Adults (35-64)
# 71129  2011-07-08    8       July  2011            22     Youth (<25)
# 70307  2011-04-30   30      April  2011            44  Adults (35-64)
# 70601  2011-09-30   30  September  2011            19     Youth (<25)
#
#        Customer_Gender    Country             State Product_Category  \
# 112073               M  Australia        Queensland         Clothing
# 112072               M  Australia        Queensland         Clothing
# 71129                M     Canada           Alberta            Bikes
# 70307                M     Canada  British Columbia            Bikes
# 70601                F     Canada  British Columbia            Bikes
#
#        Sub_Category                  Product  Order_Quantity  Unit_Cost  \
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58274      2015-07-24

# %%
sales.sort_values(['Revenue'], ascending=False).head(1)
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group  \
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)
#
#        Customer_Gender    Country       State Product_Category Sub_Category  \
# 112073               M  Australia  Queensland         Clothing        Vests
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price  \
# 112073  Touring-1000 Yellow, 50              29       1482        2384
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58274      2015-07-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here

# %%
sales.loc[sales['Year'] == 2016]['Month'].unique()
# Out:
# array(['March', 'May', 'February', 'January', 'June', 'July', 'April'],
#       dtype=object)

# %%
sales.sort_values(['Month'], ascending=True).head(5)
# Out:
#             Date  Day  Month  Year  Customer_Age             Age_Group  \
# 12694 2016-04-28   28  April  2016            29  Young Adults (25-34)
# 37262 2014-04-07    7  April  2014            38        Adults (35-64)
# 37263 2016-04-07    7  April  2016            38        Adults (35-64)
# 37264 2014-04-17   17  April  2014            38        Adults (35-64)
# 37265 2016-04-17   17  April  2016            38        Adults (35-64)
#
#       Customer_Gender        Country       State Product_Category  \
# 12694               M        Germany      Hessen      Accessories
# 37262               M  United States  Washington      Accessories
# 37263               M  United States  Washington      Accessories
# 37264               M  United States  Washington      Accessories
# 37265               M  United States  Washington      Accessories
#
#             Sub_Category                 Product  Order_Quantity  Unit_Cost  \
# ...

# %%
month_in_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July']

profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month','Date']]
profit_2016.sort_values(['Date'], ascending=True)
profit_2016.shape[0]
index_list = [0] * profit_2016.shape[0]
index_list = [i for i in range(profit_2016.shape[0])]

# %%
sorted_2016 = profit_2016.sort_values(['Date'], ascending=True)
sorted_2016
# Out:
#         Profit    Month       Date
# 112205      77  January 2016-01-01
# 88196       19  January 2016-01-01
# 88197       49  January 2016-01-01
# 61835      835  January 2016-01-01
# 6863        20  January 2016-01-01
# ...        ...      ...        ...
# 22465       24     July 2016-07-31
# 45355        3     July 2016-07-31
# 22095       39     July 2016-07-31
# 72825      469     July 2016-07-31
# 42911       81     July 2016-07-31
#
# [29398 rows x 3 columns]

# %%
sorted_2016 = sorted_2016.reset_index(drop=True)
sorted_2016
# Out:
#        Profit    Month       Date
# 0          77  January 2016-01-01
# 1          19  January 2016-01-01
# 2          49  January 2016-01-01
# 3         835  January 2016-01-01
# 4          20  January 2016-01-01
# ...       ...      ...        ...
# 29393      24     July 2016-07-31
# 29394       3     July 2016-07-31
# 29395      39     July 2016-07-31
# 29396     469     July 2016-07-31
# 29397      81     July 2016-07-31
#
# [29398 rows x 3 columns]

# %%
s_profit_2016 = sorted_2016[['Month', 'Profit'] ]
s_profit_2016
# Out:
#          Month  Profit
# 0      January      77
# 1      January      19
# 2      January      49
# 3      January     835
# 4      January      20
# ...        ...     ...
# 29393     July      24
# 29394     July       3
# 29395     July      39
# 29396     July     469
# 29397     July      81
#
# [29398 rows x 2 columns]

# %%
s_profit_2016.boxplot(by='Month', figsize=(14,6)) # MF can't specifiy the column order.
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x = 'Month', y = 'Profit', data = profit_2016, order = month_in_order)
plt.show()
#profit_2016.boxplot(by='Month', figsize=(14,6))

# profit_2016.groupby('Month').boxplot(figsize=(14,6), subplots=False)
# plt.xticks(range(1, len(month_in_order) + 1), month_in_order) # Set x-axis labels to be the months in order
# plt.show()

# for position, column in enumerate(month_in_order):
#   profit_2016.loc[profit_2016['Month']==column].boxplot(by='Month', figsize=(14,6),ylabel = 'Profit', xlabel='Month', positions=[position],ax=ax)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072
sales.loc[sales['Country'] == 'United States', 'Unit_Price']
# Out:
# 22        128.640
# 23        128.640
# 34        128.640
# 35        128.640
# 38        128.640
#            ...
# 113021     68.608
# 113022     68.608
# 113023     68.608
# 113024     68.608
# 113025     68.608
# Name: Unit_Price, Length: 39206, dtype: float64

# %%
sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072
sales.loc[sales['Country'] == 'United States', 'Unit_Price']
# Out:
# 22        147.831030
# 23        147.831030
# 34        147.831030
# 35        147.831030
# 38        147.831030
#              ...
# 113021     78.843216
# 113022     78.843216
# 113023     78.843216
# 113024     78.843216
# 113025     78.843216
# Name: Unit_Price, Length: 39206, dtype: float64

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
